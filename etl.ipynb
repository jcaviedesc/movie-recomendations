# %%
import pandas as pd

# %% [markdown]
# ## carga de datos

# %%
df = pd.read_csv('Dataset/movies_dataset.csv')

# Imprimir el nombre de las columnas
print(df.columns)

# describo los datos
print(df.describe())
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000
# /var/folders/yb/vt_hbt594dq36_5027z8x0_m0000gn/T/ipykernel_77883/2846447707.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Dataset/movies_dataset.csv')

# %%
# pendiente ver como des anidar los datos
data_anidada = df[["belongs_to_collection", "production_companies"]]

# %%
#Los valores nulos de los campos revenue, budget deben ser rellenados por el número 0
df['revenue'] = df['revenue'].fillna(0).astype("Float64")
print(df["revenue"])
df["budget"] = df["budget"].fillna(0).astype("Float64")
print(df["budget"])
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45460            0.0
# 45462            0.0
# 45463            0.0
# 45464            0.0
# 45465            0.0
# Name: revenue, Length: 45376, dtype: Float64
# 0        30000000.0
# 1        65000000.0
# 2               0.0
# 3        16000000.0
# 4               0.0
#             ...
# 45460           0.0
# 45462           0.0
# 45463           0.0
# 45464           0.0
# 45465           0.0
# Name: budget, Length: 45376, dtype: Float64

# %%
#Los valores nulos del campo release_date deben eliminarse.
num_datos = len(df)
print("numero de datos", len(df))
df=df.dropna(subset=['release_date'])
print("numero de datos borrados despues de borrar filas con valores nulos de release_date", num_datos- len(df))
df['release_date']
# Out:
# numero de datos 45376
# numero de datos borrados despues de borrar filas con valores nulos de release_date 0
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45460   1991-05-13
# 45462   2011-11-17
# 45463   2003-08-01
# 45464   1917-10-21
# 45465   2017-06-09
# Name: release_date, Length: 45376, dtype: datetime64[ns]

# %%
# De haber fechas, deberán tener el formato AAAA-mm-dd, además deberán crear la columna release_year 
# donde extraerán el año de la fecha de estreno.

# Convierto la columna 'release_date' al tipo de dato datetime para poder obtener el año
df['release_date'] = pd.to_datetime(df['release_date'], format='%Y-%m-%d', errors="coerce")

# borro los datos que no pueden ser convertidos a fecha
df=df.dropna(subset=['release_date'])

# creo la columna 'year' con el año extraído de 'release_date'
df['year'] = df['release_date'].dt.year

df['year']
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 45460    1991
# 45462    2011
# 45463    2003
# 45464    1917
# 45465    2017
# Name: year, Length: 45376, dtype: int32

# %%
'''
Crear la columna con el retorno de inversión, llamada return con los campos revenue y budget,
dividiendo estas dos últimas revenue / budget, cuando no hay datos disponibles para calcularlo, 
deberá tomar el valor 0.
'''
#creo la columna retorno de inversión 
df['return_of_investment'] = df.apply(lambda row: row['revenue'] / row['budget'] if row['revenue'] > 0 and row['budget'] > 0 else 0, axis=1)
# Out:
# 5381
# 0        12.451801
# 1         4.043035
# 3         5.090760
# 5         3.123947
# 8         1.838576
#            ...
# 45250     1.583333
# 45399     0.000004
# 45409     1.660765
# 45412     0.634397
# 45422     0.282600
# Name: return_of_investment, Length: 5381, dtype: float64

# %%
# Eliminar las columnas no utilizadas
columnas_no_utilizadas = ['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage']
df = df.drop(columnas_no_utilizadas, axis=1)
df
# Out:
#                                    belongs_to_collection      budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                    NaN  65000000.0
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                    NaN  16000000.0
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...                                                  ...         ...
# 45460                                                NaN         0.0
# 45462                                                NaN         0.0
# 45463                                                NaN         0.0
# 45464                                                NaN         0.0
# 45465                                                NaN         0.0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...   30840
# 45462                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464                                                 []  227506
# 45465                                                 []  461257
#
#       original_language                                           overview  \
# 0                    en  Led by Woody, Andy's toys live happily in his ...
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45460                en  Yet another version of the classic epic, with ...
# 45462                tl  An artist struggles to finish his work while a...
# 45463                en  When one of her hits goes wrong, a professiona...
# 45464                en  In a small town live two brothers, one a minis...
# 45465                en  50 years after decriminalisation of homosexual...
#
#       popularity                               production_companies  \
# 0      21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2        11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3       3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4       8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...          ...                                                ...
# 45460   5.683753  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45462   0.178241             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463   0.903007  [{'name': 'American World Pictures', 'id': 6165}]
# 45464   0.003503               [{'name': 'Yermoliev', 'id': 88753}]
# 45465   0.163015                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45460  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...   1991-05-13
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45460          0.0    104.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45460           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45460                                                NaN
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  vote_average  vote_count  year  \
# 0                        Toy Story           7.7      5415.0  1995
# 1                          Jumanji           6.9      2413.0  1995
# 2                 Grumpier Old Men           6.5        92.0  1995
# 3                Waiting to Exhale           6.1        34.0  1995
# 4      Father of the Bride Part II           5.7       173.0  1995
# ...                            ...           ...         ...   ...
# 45460                   Robin Hood           5.7        26.0  1991
# 45462          Century of Birthing           9.0         3.0  2011
# 45463                     Betrayal           3.8         6.0  2003
# 45464             Satan Triumphant           0.0         0.0  1917
# 45465                     Queerama           0.0         0.0  2017
#
#        return_of_investment
# 0                 12.451801
# 1                  4.043035
# 2                  0.000000
# 3                  5.090760
# 4                  0.000000
# ...                     ...
# 45460              0.000000
# 45462              0.000000
# 45463              0.000000
# 45464              0.000000
# 45465              0.000000
#
# [45376 rows x 20 columns]

# %% [markdown]
# ## Metodos para el api
# 1. peliculas_idioma

# %%
idioma = 'en'
pelis_por_idioma = df[df['original_language'] == idioma]
print(f'{len(pelis_por_idioma)} cantidad de películas fueron estrenadas en {idioma}')
# Out:
# 32202 cantidad de películas fueron estrenadas en en

# %%
# def peliculas_duracion( Pelicula: str ): Se ingresa una pelicula. Debe devolver la la duracion y el año.
pelicula = 'Waiting to Exhale'
peli_data = df[df['title'] == pelicula]
duracion = peli_data["runtime"]
year = peli_data["year"]
print(f'Duración: {duracion}. Año: {year}')
# Out:
# Duración: 3    127.0
# Name: runtime, dtype: float64. Año: 3    1995
# Name: year, dtype: int32
